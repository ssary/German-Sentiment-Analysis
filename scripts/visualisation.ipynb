# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np

# data to plot

n_groups = 3
weighted_f1_score = (62, 77, 87)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
opacity = 0.9

rects1 = plt.bar(index, weighted_f1_score, bar_width,
alpha=opacity,
label='F1 Score')

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}%'.format(height),
        xy=(rect.get_x() + rect.get_width() / 2, height),
        xytext=(0, 3),  # 3 points vertical offset
        textcoords="offset points",
        ha='center', va='bottom')
autolabel(rects1)

ax.annotate('+15%', xy=(0, 62), xytext=(0.3, 62), color='black')
ax.annotate('+10%', xy=(1, 77), xytext=(1.3, 77), color='black')
plt.xlabel('Models')
plt.ylabel('F1 Score')
plt.title('F1 Score of SA models tested on GermEval2017 Dataset')
plt.xticks(index , ('XLM-T Base', 'German Sentiment', 'XLM-T Fine Tuned'))
plt.legend()
plt.show()

# %%
n_groups = 2
weighted_f1_score = (62, 87)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
opacity = 0.9

rects1 = plt.bar(index, weighted_f1_score, bar_width,
alpha=opacity,
label='F1 Score')

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}%'.format(height),
        xy=(rect.get_x() + rect.get_width() / 2, height),
        xytext=(0, 2),  # 3 points vertical offset
        textcoords="offset points",
        ha='center', va='bottom')
autolabel(rects1)

ax.annotate('+25%', xy=(0, 62), xytext=(0.45, 62), color='black')
plt.xlabel('Models')
plt.ylabel('F1 Score')
plt.title('F1 Score of SA models tested on GermEval2017 Dataset')
plt.xticks(index , ('XLM-T Base', 'XLM-T Fine Tuned'))
plt.legend()
plt.show()

# %%
# Weighted F1 Score between xlm-t Base & fine tuned models
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np

# data to plot

n_groups = 4
weighted_f1_score = (78, 80, 86.5, 87.3)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
opacity = 0.9
bar_width = 0.4
rects1 = plt.bar(index, weighted_f1_score, bar_width,
alpha=opacity,
label='F1 Score')

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}%'.format(height),
        xy=(rect.get_x() + rect.get_width() / 2, height),
        xytext=(0, 4),  # 3 points vertical offset
        textcoords="offset points",
        ha='center', va='bottom')
autolabel(rects1)

ax.annotate('+2%', xy=(0, 62), xytext=(0.3, 78), color='black')
ax.annotate('+7%', xy=(0, 62), xytext=(1.3, 80), color='black')
ax.annotate('+1%', xy=(1, 77), xytext=(2.3, 86), color='black')
plt.xlabel('Models')
plt.ylabel('F1 Score')
plt.xticks(index , ('XLM-T Base','XLM-T 1K', 'XLM-T 100K', 'XLM-T 200K'))
plt.legend()
plt.show()

# %%
# Macro F1 Score between the xlm-t Base and Fine tuned models
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np

# data to plot

n_groups = 4
weighted_f1_score = (68, 79, 82, 81)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
opacity = 0.9
bar_width = 0.4
rects1 = plt.bar(index, weighted_f1_score, bar_width,
alpha=opacity,
label='F1 Score')

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}%'.format(height),
        xy=(rect.get_x() + rect.get_width() / 2, height),
        xytext=(0, 4),  # 3 points vertical offset
        textcoords="offset points",
        ha='center', va='bottom')
autolabel(rects1)

ax.annotate('+11%', xy=(0, 62), xytext=(0.3, 68), color='black')
ax.annotate('+3%', xy=(0, 62), xytext=(1.3, 79), color='black')
ax.annotate('-1%', xy=(1, 77), xytext=(2.3, 82), color='black')
plt.xlabel('Models')
plt.ylabel('F1 Score')
plt.xticks(index , ('XLM-T Base','XLM-T 1K', 'XLM-T 100K', 'XLM-T 200K'))
plt.legend()
plt.show()

# %%
n_groups = 2
weighted_f1_score = (69, 77)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
opacity = 0.9

rects1 = plt.bar(index, weighted_f1_score, bar_width,
alpha=opacity,
label='F1 Score')

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}%'.format(height),
        xy=(rect.get_x() + rect.get_width() / 2, height),
        xytext=(0, 2),  # 3 points vertical offset
        textcoords="offset points",
        ha='center', va='bottom')
autolabel(rects1)

ax.annotate('+8%', xy=(0, 62), xytext=(0.45, 69), color='black')
plt.xlabel('Models')
plt.ylabel('F1 Score')
plt.title('F1 Score of German Sentiment and XLM-t base model')
plt.xticks(index , ('German Sentiment Model', 'XLM-T Base Model'))
plt.legend()
plt.show()
